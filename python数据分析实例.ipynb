# %%
from sklearn.linear_model import  LinearRegression

# %%
mdoel = LinearRegression()

# %%
mdoel
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(mdoel)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
import pandas as pd

# %% [markdown]
# ## Import multiple csv files one time

# %%
import os
import glob
import pandas as pd
import numpy as np

path = "examples/11"
allFiles = glob.glob(os.path.join(path,"*.csv"))

np_array_list = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0, engine='python')
    np_array_list.append(df.as_matrix())
    print('file ', file_, 'is added')

comb_np_array = np.vstack(np_array_list)
big_frame = pd.DataFrame(comb_np_array)

big_frame.columns = ['first_name', 'last_name','company_name','address','city','province','postal','phone1','phone2','email','web']
# Out:
# file  examples/11\1.csv is added
# file  examples/11\2.csv is added
# file  examples/11\ca-500 - 副本 (20).csv is added
# file  examples/11\ca-500.csv is added

# %%
df
# Out:
#        first_name      last_name                    company_name  \
# 0       Francoise  Rautenstrauch               Riebesell, H F Jr
# 1          Kendra           Loud               Deloitte & Touche
# 2         Lourdes       Bauswell               Oklahoma Neon Inc
# 3          Hannah        Edmison              M B A Paint Stores
# 4             Tom          Loeza       Sheraton Shreveport Hotel
# 5         Queenie     Kramarczyk        Goeman Wood Products Inc
# 6             Hui        Portaro     A Storage Inn Of Gloucester
# 7          Josefa          Opitz               Norman Gale Isuzu
# 8             Lea      Steinhaus          James, Christopher Esq
# 9           Paola         Vielma                  Congress Title
# 10      Hortencia        Bresser     Batavia Chamber Of Commerce
# 11         Leanna       Tijerina       Stephenson Land Surveying
# 12       Herschel        Geneseo           Molded Dimensions Inc
# ...

# %%
big_frame
# Out:
#         first_name    last_name                    company_name  \
# 0         Willetta         Cesa               Alpha Services Co
# 1            Johna     Magathan                  Park Metal Inc
# 2            Ollie    Oliverson          Redemann, Robert P Esq
# 3           Sherly      Vitrano     Stangels Financial Services
# 4           Kindra      Dishong        Mcclanathan, Peter D Esq
# 5            Vanda      Tentler    Oklahoma Ford Power Products
# 6         Marshall    Fitgerald          Mpw Communities Of N J
# 7           Kelvin        Hasha    Orourke, Denise Michelle Esq
# 8           Darrin    Mathiasen           Milton Daily Standard
# 9           Susana     Mccarley                   Kinkos Copies
# 10          Wilson    Nickelson      Brobeck Phleger & Harrison
# 11         Malissa        Talty          Stafford, William P Ii
# 12          Tandra  Castillanos          Stony Creek Apartments
# 13          Lorean       Sammon         Arizona Store Equipment
# ...

# %%
data
# Out:
#        first_name      last_name                    company_name  \
# 0       Francoise  Rautenstrauch               Riebesell, H F Jr
# 1          Kendra           Loud               Deloitte & Touche
# 2         Lourdes       Bauswell               Oklahoma Neon Inc
# 3          Hannah        Edmison              M B A Paint Stores
# 4             Tom          Loeza       Sheraton Shreveport Hotel
# 5         Queenie     Kramarczyk        Goeman Wood Products Inc
# 6             Hui        Portaro     A Storage Inn Of Gloucester
# 7          Josefa          Opitz               Norman Gale Isuzu
# 8             Lea      Steinhaus          James, Christopher Esq
# 9           Paola         Vielma                  Congress Title
# 10      Hortencia        Bresser     Batavia Chamber Of Commerce
# 11         Leanna       Tijerina       Stephenson Land Surveying
# 12       Herschel        Geneseo           Molded Dimensions Inc
# ...

# %%
data1 = data.groupby('province')

# %%
np_array_list
# Out:
# [array([['Willetta', 'Cesa', 'Alpha Services Co', ..., '902-906-9598',
#          'willetta_cesa@gmail.com', 'http://www.alphaservicesco.com'],
#         ['Johna', 'Magathan', 'Park Metal Inc', ..., '780-550-9766',
#          'jmagathan@magathan.org', 'http://www.parkmetalinc.com'],
#         ['Ollie', 'Oliverson', 'Redemann, Robert P Esq', ...,
#          '416-291-7332', 'ooliverson@cox.net',
#          'http://www.redemannrobertpesq.com'],
#         ...,
#         ['Leslee', 'Matsuno', 'Factory Mattress Outlet', ...,
#          '418-543-9015', 'leslee_matsuno@matsuno.org',
#          'http://www.factorymattressoutlet.com'],
#         ['Daniel', 'Dobler', 'Cosgroves N End Plbg & Hdwr Co', ...,
#          '506-951-8403', 'ddobler@dobler.com',
#          'http://www.cosgrovesnendplbghdwrco.com'],
#         ['Antonio', 'Unruh', 'Mission Lincoln Properties', ...,
#          '604-966-9833', 'antonio.unruh@hotmail.com',
# ...

# %%
import glob, os    
df = pd.concat(map(pd.read_csv(engine='python'), glob.glob(os.path.join('', "examples/11/*.csv"))))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-2cfe3717ba89> in <module>()
#       1 import glob, os
# ----> 2 df = pd.concat(map(pd.read_csv(engine='python'), glob.glob(os.path.join('', "examples/11/*.csv"))))
#
# TypeError: parser_f() missing 1 required positional argument: 'filepath_or_buffer'

# %%
group1 = big_frame.groupby('province')

# %%
data1 = group1[['city']].count()

# %%
data.sum(axis=0)

# %%
data.sum(axis=0)

# %%
data1.sum(axis=0)

# %%
data1
